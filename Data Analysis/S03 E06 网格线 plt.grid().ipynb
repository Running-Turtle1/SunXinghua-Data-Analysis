# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif']=['SimHei'] # 用黑体显示中文
数据 = pd.read_excel(r'./repo2/12.日期.xlsx')
plt.grid(axis='x',color='r',linestyle=':',linewidth=3)
plt.show()

# %% [markdown]
# ???
